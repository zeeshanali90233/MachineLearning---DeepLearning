# %% [markdown]
# ## PCA
#
# PCA (Principal Component Analysis) is a way to compress big data into fewer important features without losing much information.
# It keeps what matters most and removes noise, making data simpler and faster to analyze.

# %% [markdown]
# https://builtin.com/data-science/step-step-explanation-principal-component-analysis

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#
# File c:\Users\786\Desktop\Sessions\MachineLearning---DeepLearning\06-b-PCA\.venv\Lib\site-packages\pandas\__init__.py:61
#      58 # let init-time option registration happen
#      59 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 61 from pandas.core.api import (
#      62     # dtype
#      63     ArrowDtype,
#      64     Int8Dtype,
#      65     Int16Dtype,
#      66     Int32Dtype,
#      67     Int64Dtype,
#      68     UInt8Dtype,
#      69     UInt16Dtype,
#      70     UInt32Dtype,
#      71     UInt64Dtype,
#      72     Float32Dtype,
#      73     Float64Dtype,
#      74     CategoricalDtype,
#      75     PeriodDtype,
#      76     IntervalDtype,
#      77     DatetimeTZDtype,
#      78     StringDtype,
# ...

# %%
dataset=pd.read_csv("credit.csv")

# %%
dataset.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
dataset.drop(columns=["CUST_ID"],inplace=True)

# %%
dataset.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
# Check missing values count per column
print(dataset.isnull().sum())
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [markdown]
# ### Filling Null Values

# %%
dataset["MINIMUM_PAYMENTS"] = dataset["MINIMUM_PAYMENTS"].fillna(dataset["MINIMUM_PAYMENTS"].mean())
dataset["CREDIT_LIMIT"] = dataset["CREDIT_LIMIT"].fillna(dataset["CREDIT_LIMIT"].mean())

# %%
# Check missing values count per column
print(dataset.isnull().sum())
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# ### Reducing the Whole Data to 2 columsns

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_data = pca.fit_transform(dataset)

# %%
pca_data
# Out:
# array([[-4326.38395637,   921.5668839 ],
#        [ 4118.91667599, -2432.8463473 ],
#        [ 1497.90766006, -1997.57869196],
#        ...,
#        [-4379.44420243,   911.50456628],
#        [-4791.11774446,  1032.54094369],
#        [-3623.70274869,  1555.134769  ]], shape=(8950, 2))

# %%
pca.explained_variance_ratio_
# Out:
# array([0.47529109, 0.17778772])

# %%
pca_df = pd.DataFrame(pca_data, columns=["PC1", "PC2"])

pca_df
# Out:
#               PC1          PC2
# 0    -4326.383956   921.566884
# 1     4118.916676 -2432.846347
# 2     1497.907660 -1997.578692
# 3     1394.548556 -1488.743450
# 4    -3743.351874   757.342659
# ...           ...          ...
# 8945 -4208.357938  1122.443274
# 8946 -4123.924001   951.683803
# 8947 -4379.444202   911.504566
# 8948 -4791.117744  1032.540944
# 8949 -3623.702749  1555.134769
#
# [8950 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(pca_df["PC1"], pca_df["PC2"])
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("Customers in PCA Space")
plt.show()
